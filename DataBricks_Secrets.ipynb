# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScientistMSBA/Security/blob/main/DataBricks_Secrets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Open up command prompt:**
# *   run cmd
# *   run: `cd C:\Users\{computer_user}\Anaconda3\Scripts`
# *   run: `pip install databricks-cli`
# *   run: `databricks configure --token`
#   *   Databricks Host: https://dx2-{company}.cloud.databricks.com/
#   *   Token: *{located in secure location}*
#       *    Note: very finicky about copy/paste, so make sure it goes through
# *   run: `databricks workspace ls`
# *   run: `databricks secrets put --scope {username} --key {secrets_name} `
#     *    Note, a window will pop-up where you can save the password or key
#
# To Modify:
# *   run: `databricks secrets put --scope {username}  --key {secrets_name} --string-value my-value`

# %% [markdown]
# **Open Databricks notebook:**

# %%
key = dbutils.secrets.get(scope = '{username}', key = '{secrets_name}')
