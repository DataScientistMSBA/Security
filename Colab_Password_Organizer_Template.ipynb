# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScientistMSBA/Security/blob/main/Colab_Password_Organizer_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# cd <enter directory location for password file>
# ls

# %%
import json
fileObject = open("Password_File.txt", "r")
data = fileObject.read()
data = json.loads(data)

# %%
'data['ABC']['password']'
# Out:
# 'test'
